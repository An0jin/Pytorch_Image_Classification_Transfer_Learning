# %%
# %pip install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting roboflow
#   Downloading roboflow-1.4.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (2025.1.31)
# Requirement already satisfied: idna>=3.7 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (3.19)
# Requirement already satisfied: cycler in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (3.10.1)
# Requirement already satisfied: numpy<2.4,>=1.18.5 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (2.1.1)
# Collecting opencv-python-headless>=4.10.0 (from roboflow)
#   Downloading opencv_python_headless-5.0.0.93-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (11.1.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.4.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.6.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests_toolbelt in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (0.15.4)
# Requirement already satisfied: click>=8.0 in /home/an0jin/.local/lib/python3.13/site-packages (from roboflow) (8.5.0)
# Collecting click>=8.0 (from roboflow)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/an0jin/.local/lib/python3.13/site-packages (from typer<0.26,>=0.12.0->roboflow) (4.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/an0jin/.local/lib/python3.13/site-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/an0jin/.local/lib/python3.13/site-packages (from typer<0.26,>=0.12.0->roboflow) (14.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/an0jin/.local/lib/python3.13/site-packages (from rich>=10.11.0->typer<0.26,>=0.12.0->roboflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/an0jin/.local/lib/python3.13/site-packages (from rich>=10.11.0->typer<0.26,>=0.12.0->roboflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/an0jin/.local/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib->roboflow) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/an0jin/.local/lib/python3.13/site-packages (from requests->roboflow) (3.4.1)
# Downloading roboflow-1.4.2-py3-none-any.whl (302 kB)
# Downloading pi_heif-1.4.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.2 MB/s eta 0:00:00a 0:00:01
# Downloading pillow_avif_plugin-1.6.0-cp313-cp313-manylinux_2_28_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 6.2 MB/s eta 0:00:00a 0:00:01
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading opencv_python_headless-5.0.0.93-cp37-abi3-manylinux_2_28_x86_64.whl (61.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 MB 10.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pillow-avif-plugin, pi-heif, opencv-python-headless, click, roboflow
#   Attempting uninstall: click╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [opencv-python-headless]
#     Found existing installation: click 8.5.00m━━━━━━━━━━━━━━━ 3/5 [click]hon-headless]
#     Uninstalling click-8.5.0:╺━━━━━━━━━━━━━━━ 3/5 [click]
#       Successfully uninstalled click-8.5.0━━━━━━━━━━━━━━━ 3/5 [click]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [roboflow]4/5 [roboflow]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# huggingface-hub 1.30.0 requires click<9.0.0,>=8.4.2, but you have click 8.1.8 which is incompatible.
# Successfully installed click-8.1.8 opencv-python-headless-5.0.0.93 pi-heif-1.4.0 pillow-avif-plugin-1.6.0 roboflow-1.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import shutil
from roboflow import Roboflow
rf=Roboflow(api_key=os.getenv('roboflow'))
rf

# %%
link='https://universe.roboflow.com/2-6164q/class-bgche'

# %%
linklist=link.split("/")
version=1
while True:
    try:
        rf.workspace(linklist[-2]).project(linklist[-1]).version(version).download("folder")
        version+=1
    except:
        try:
            rf.workspace(linklist[-2]).project(linklist[-1]).version(version).download("yolov8")
            version+=1
        except:
            break
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in class-1 to folder:: 100%|██████████| 5119/5119 [00:01<00:00, 3484.62it/s]
# Extracting Dataset Version Zip to class-1 in folder:: 100%|██████████| 121/121 [00:00<00:00, 10706.98it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
